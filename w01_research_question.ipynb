# %% [markdown]
# <a href="https://colab.research.google.com/github/asad-masood314/FlyRank-assignment-1/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/asad-masood314/FlyRank-assignment-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose Lane 2 because I want to investigate whether the available page-level search data can help identify which pages should receive attention first. The starter dataset contains information for around 30,000 pages, which makes manual prioritization difficult. I want to explore whether data-driven ranking can help create a useful review priority list.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Decision: Which pages should be prioritized for review?
Action: The SEO/content team reviews the highest-priority pages first.
Cost: A wrong recommendation could waste time or cause important pages to be missed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
The dataset has ~30,000 pages and 44 columns, giving enough data to investigate page prioritization.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
The starter data shows measurable differences between pages, and the existing starter workflow suggests that a learned ranking approach can outperform the initial hand-written baseline on the provided sample.
I cannot claim that these relationships cause changes in Google rankings, or that a model trained on this sample will generalize to all websites or search results.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✔] Every section above is filled — markdown thinking AND the code that backs it
# - [✔] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✔] No client names, URLs, or private queries anywhere
# - [✔] My claims use careful words: observed, measured, directional, decision-support
# - [✔] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
